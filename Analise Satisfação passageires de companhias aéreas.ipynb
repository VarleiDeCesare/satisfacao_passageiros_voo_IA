# %%
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(20,8.27)})

# %%
df = pd.read_csv('airline_passenger_satisfaction.csv')
df.columns = ["Id", "genero", "idade", "tipo_cliente", "tipo_voo", "classe", "distancia_voo", "atraso_partida", "atraso_chegada", "conveniencia_hora_partida_chegada", "facilidade_reserva_online", "servico_checkin", "embarque_online", "localizacao_portao", "servico_bordo", "conforto_assento", "servico_quarto_pernas", "limpeza", "comida_bebida", "servico_voo", "servico_wifi_voo", "entreterimento_voo", "manuseio_bagagem", "satisfacao"]

# %%
df.describe()
# Out:
#                   Id          idade  distancia_voo  atraso_partida  \
# count  129880.000000  129880.000000  129880.000000   129880.000000
# mean    64940.500000      39.427957    1190.316392       14.713713
# std     37493.270818      15.119360     997.452477       38.071126
# min         1.000000       7.000000      31.000000        0.000000
# 25%     32470.750000      27.000000     414.000000        0.000000
# 50%     64940.500000      40.000000     844.000000        0.000000
# 75%     97410.250000      51.000000    1744.000000       12.000000
# max    129880.000000      85.000000    4983.000000     1592.000000
#
#        atraso_chegada  conveniencia_hora_partida_chegada  \
# count   129487.000000                      129880.000000
# mean        15.091129                           3.057599
# std         38.465650                           1.526741
# min          0.000000                           0.000000
# 25%          0.000000                           2.000000
# ...

# %%
df
# Out:
#             Id  genero  idade tipo_cliente  tipo_voo        classe  \
# 0            1    Male     48   First-time  Business      Business
# 1            2  Female     35    Returning  Business      Business
# 2            3    Male     41    Returning  Business      Business
# 3            4    Male     50    Returning  Business      Business
# 4            5  Female     49    Returning  Business      Business
# ...        ...     ...    ...          ...       ...           ...
# 129875  129876    Male     28    Returning  Personal  Economy Plus
# 129876  129877    Male     41    Returning  Personal  Economy Plus
# 129877  129878    Male     42    Returning  Personal  Economy Plus
# 129878  129879    Male     50    Returning  Personal  Economy Plus
# 129879  129880  Female     20    Returning  Personal  Economy Plus
#
#         distancia_voo  atraso_partida  atraso_chegada  \
# 0                 821               2             5.0
# ...

# %%
df['satisfacao'].value_counts()
# Out:
# Neutral or Dissatisfied    73452
# Satisfied                  56428
# Name: satisfacao, dtype: int64

# %%
#Idade dos Passageiros

# %%
chart = sns.countplot(x="idade", data=df)
chart.set_xticklabels(chart.get_xticklabels());

# %%
##Generos

# %%
chart = sns.countplot(x="genero", data=df)
chart.set_xticklabels(chart.get_xticklabels());

# %%
#Tipo Passageiro

# %%
chart = sns.countplot(x="tipo_cliente", data=df)
chart.set_xticklabels(chart.get_xticklabels());

# %%
#Tipo Viagem

# %%
chart = sns.countplot(x="tipo_voo", data=df)
chart.set_xticklabels(chart.get_xticklabels());

# %%
#Classe

# %%
chart = sns.countplot(x="classe", data=df)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45);

# %%
#Satisfação

# %%
sns.histplot(x="satisfacao",data=df, shrink= 0.60)
# Out:
# <AxesSubplot:xlabel='satisfacao', ylabel='Count'>
