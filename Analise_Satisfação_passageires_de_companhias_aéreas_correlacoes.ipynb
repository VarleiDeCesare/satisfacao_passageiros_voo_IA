# %% [markdown]
# <a href="https://colab.research.google.com/github/VarleiDeCesare/satisfacao_passageiros_voo_IA/blob/master/Analise_Satisfa%C3%A7%C3%A3o_passageires_de_companhias_a%C3%A9reas_correlacoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(20,8.27)})

# %%
df
# Out:
#             Id  genero  idade tipo_cliente  tipo_voo        classe  \
# 0            1    Male     48   First-time  Business      Business
# 1            2  Female     35    Returning  Business      Business
# 2            3    Male     41    Returning  Business      Business
# 3            4    Male     50    Returning  Business      Business
# 4            5  Female     49    Returning  Business      Business
# ...        ...     ...    ...          ...       ...           ...
# 129875  129876    Male     28    Returning  Personal  Economy Plus
# 129876  129877    Male     41    Returning  Personal  Economy Plus
# 129877  129878    Male     42    Returning  Personal  Economy Plus
# 129878  129879    Male     50    Returning  Personal  Economy Plus
# 129879  129880  Female     20    Returning  Personal  Economy Plus
#
#         distancia_voo  atraso_partida  atraso_chegada  \
# 0                 821               2             5.0
# ...

# %%
# Correlação entre atrasos do voo com avaliações negativas
sns.scatterplot(x="atraso_partida", y="satisfacao", data=df)

df.query("atraso_partida >= 600").atraso_partida.count()
# Out:
# 25

# %%
df.query("atraso_partida <= 600").atraso_partida.count()
# Out:
# 129856

# %%
# Qual classe mais utilizada pela primeira viagem
df.query("tipo_cliente == 'First-time'").classe.describe()
# Out:
# count       23780
# unique          3
# top       Economy
# freq        13634
# Name: classe, dtype: object

# %%
df.classe.describe()
# Out:
# count       129880
# unique           3
# top       Business
# freq         62160
# Name: classe, dtype: object
